# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snb
import warnings

# %%
data=pd.read_csv("hotel_booking.csv")

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
data.shape
# Out:
# (119390, 36)

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
data.drop(columns=['name', 'email',
       'phone-number', 'credit_card'],axis=0 ,inplace = True)

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data.drop(columns=['agent','company'],inplace =True)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118898 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
# ...

# %%
data['reservation_status_date']=pd.to_datetime(data["reservation_status_date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118898 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
# ...

# %%
data['required_car_parking_spaces'].astype('int64')
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: required_car_parking_spaces, Length: 118898, dtype: int64

# %%
data.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       118898             118898  118898  118898         118898
# unique           2                 12       5     177              7
# top     City Hotel             August      BB     PRT      Online TA
# freq         79302              13852   91863   48586          56402
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                118898             118898             118898
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97730              85601              73863
#
#        deposit_type customer_type reservation_status
# count        118898        118898             118898
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104163         89174              74745

# %%
data['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79302
# Resort Hotel    39596
# Name: count, dtype: int64

# %%
for cols in data.describe(include='object').columns:
    print(cols)
    print()
    print(data[cols].value_counts())
    print("*"*100)
    print()
# Out:
# hotel
#
# hotel
# City Hotel      79302
# Resort Hotel    39596
# Name: count, dtype: int64
# ****************************************************************************************************
#
# arrival_date_month
#
# arrival_date_month
# August       13852
# July         12628
# May          11779
# October      11095
# April        11045
# June         10927
# September    10467
# March         9739
# February      8012
# November      6752
# December      6728
# January       5874
# Name: count, dtype: int64
# ****************************************************************************************************
#
# meal
#
# meal
# BB           91863
# HB           14434
# SC           10638
# Undefined     1165
# FB             798
# Name: count, dtype: int64
# ****************************************************************************************************
#
# country
#
# country
# PRT    48586
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
data['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
data=data[data['adr']<5000]

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
data['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(5,6))
plt.title("Reservation Status Count")
plt.ylabel("Count")
plt.bar(['Not Cancelled'],data['is_canceled'].value_counts(),edgecolor='k')
# Out:
# <BarContainer object of 2 artists>

# %%
snb.countplot(x='hotel',hue='is_canceled',data=data)
plt.legend(["Not Cancelled","Cancelled"])

# %%
CityHotel=data[data['hotel']=='City Hotel']
CityHotel['is_canceled'].value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    58.291825
# 1    41.708175
# Name: proportion, dtype: float64

# %%
ResortHotel=data[data['hotel']=='Resort Hotel']
ResortHotel['is_canceled'].value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    72.024952
# 1    27.975048
# Name: proportion, dtype: float64

# %%
# data=data[['reservation_status_date','adr']]
# data.head()

# %%
CityHotel=CityHotel.groupby('reservation_status_date')[['adr']].mean()

# %%
ResortHotel=ResortHotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,8))
plt.plot(CityHotel.index,CityHotel['adr'],label='CityHotel')
plt.plot(ResortHotel.index,ResortHotel['adr'],label='ResortHotel')
plt.legend(fontsize=20)

# %%
data['month']=data['reservation_status_date'].dt.month
fig=plt.figure(figsize=(18,7))
snb.countplot(x = 'month', hue='is_canceled', data= data, palette='bright')
plt.title("Reservation Status per Month",size=20)
plt.xlabel("Months",size=12)
plt.ylabel("Num of Reservations",size=12)
plt.legend(['Not_canceled','canceled'])
plt.savefig("Reservation_Status_per_Month.png")
plt.show()

# %%
df=data
plt.figure(figsize=(14,5))
plt.title("ADR per month")
ax11=snb.barplot(x= 'month' , y= 'adr',data = df[df['is_canceled']==1].groupby("month")[['adr']].sum().reset_index())
plt.xlabel("Month")
plt.ylabel("ADR")
plt.show()

# %%
canceled_=df[df['is_canceled']==1]
top_ten_country=canceled_["country"].value_counts()[:10]

# %%
plt.figure(figsize=(10,5))
plt.title("Top 10 Countries with max canellations")
plt.pie(top_ten_country, autopct='%.1f',labels = top_ten_country.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1858a18b710>,
# ...
#  [Text(-0.6485414980270044, 0.888478432679651, 'PRT'),
#   Text(-0.12452901505974424, -1.0929284168728757, 'GBR'),
#   Text(0.2795827699816853, -1.0638766257087182, 'ESP'),
#   Text(0.6082427774650023, -0.9165373553007318, 'FRA'),
#   Text(0.8244337697170071, -0.7282231521657391, 'ITA'),
#   Text(0.9549224064682716, -0.5460065911917595, 'DEU'),
#   Text(1.0312598327523899, -0.38275730868464564, 'IRL'),
#   Text(1.0729025706347506, -0.24265216653750293, 'BRA'),
#   Text(1.0926161903610716, -0.12723938290033737, 'USA'),
#   Text(1.0992090719340442, -0.041706308610296686, 'BEL')],
#  [Text(-0.35374990801472966, 0.48462459964344595, '70.1'),
#   Text(-0.06792491730531504, -0.5961427728397503, '6.2'),
#   Text(0.1524996927172829, -0.5802963412956644, '5.5'),
#   Text(0.331768787708183, -0.49992946652767184, '4.9'),
#   Text(0.44969114711836744, -0.39721262845403943, '3.4'),
#   Text(0.5208667671645117, -0.297821777013687, '3.1'),
# ...

# %%
bookings["new"]=df["market_segment"].value_counts(normalize=True)*100

# %%
cancellations=canceled_['market_segment'].value_counts(normalize=True)*100

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 plt.bar(bookings,df['market_segment'])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2739, in bar(x, height, width, bottom, align, data, **kwargs)
#    2728 @_copy_docstring_and_deprecators(Axes.bar)
#    2729 def bar(
#    2730     x: float | ArrayLike,
#    (...)
#    2737     **kwargs,
#    2738 ) -> BarContainer:
# -> 2739     return gca().bar(
#    2740         x,
#    2741         height,
#    2742         width=width,
#    2743         bottom=bottom,
#    2744         align=align,
#    2745         **({"data": data} if data is not None else {}),
#    2746         **kwargs,
#    2747     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
# ...

# %%
bookings
# Out:
# market_segment
# Online TA        47.437698
# Offline TA/TO    20.319268
# Groups           16.658116
# Direct           10.469566
# Corporate         4.298679
# Complementary     0.617341
# Aviation          0.199332
# Name: proportion, dtype: float64
