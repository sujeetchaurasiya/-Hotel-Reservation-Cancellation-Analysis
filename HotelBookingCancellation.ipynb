# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snb
import warnings

# %%
data=pd.read_csv("hotel_booking.csv")

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
data.shape
# Out:
# (119390, 36)

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
data.drop(columns=['name', 'email',
       'phone-number', 'credit_card'],axis=0 ,inplace = True)

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data.drop(columns=['agent','company'],inplace =True)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118898 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
# ...

# %%
data['reservation_status_date']=pd.to_datetime(data["reservation_status_date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118898 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
# ...

# %%
data['required_car_parking_spaces'].astype('int64')
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: required_car_parking_spaces, Length: 118898, dtype: int64

# %%
data.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       118898             118898  118898  118898         118898
# unique           2                 12       5     177              7
# top     City Hotel             August      BB     PRT      Online TA
# freq         79302              13852   91863   48586          56402
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                118898             118898             118898
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97730              85601              73863
#
#        deposit_type customer_type reservation_status
# count        118898        118898             118898
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104163         89174              74745

# %%
data['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79302
# Resort Hotel    39596
# Name: count, dtype: int64

# %%
for cols in data.describe(include='object').columns:
    print(cols)
    print()
    print(data[cols].value_counts())
    print("*"*100)
    print()
# Out:
# hotel
#
# hotel
# City Hotel      79302
# Resort Hotel    39596
# Name: count, dtype: int64
# ****************************************************************************************************
#
# arrival_date_month
#
# arrival_date_month
# August       13852
# July         12628
# May          11779
# October      11095
# April        11045
# June         10927
# September    10467
# March         9739
# February      8012
# November      6752
# December      6728
# January       5874
# Name: count, dtype: int64
# ****************************************************************************************************
#
# meal
#
# meal
# BB           91863
# HB           14434
# SC           10638
# Undefined     1165
# FB             798
# Name: count, dtype: int64
# ****************************************************************************************************
#
# country
#
# country
# PRT    48586
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
data['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
data=data[data['adr']<5000]

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
data['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(5,6))
plt.title("Reservation Status Count")
plt.ylabel("Count")
plt.bar(['Not Cancelled','Cancelled'],data['is_canceled'].value_counts(),edgecolor='k')
plt.savefig("Reservation Status Count",dpi=300)

# %%
snb.countplot(x='hotel',hue='is_canceled',data=data)
plt.title("Reservation Cancellation Status")
plt.legend(["Not Cancelled","Cancelled"])
plt.savefig("Reservation Cancellation Status",dpi=300)

# %%
CityHotel=data[data['hotel']=='City Hotel']
CityHotel['is_canceled'].value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    58.291825
# 1    41.708175
# Name: proportion, dtype: float64

# %%
ResortHotel=data[data['hotel']=='Resort Hotel']
ResortHotel['is_canceled'].value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    72.024952
# 1    27.975048
# Name: proportion, dtype: float64

# %%
# data=data[['reservation_status_date','adr']]
# data.head()

# %%
CityHotel=CityHotel.groupby('reservation_status_date')[['adr']].mean()

# %%
ResortHotel=ResortHotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,8))
plt.title("ADR of Hotels Date Wise",size=18)
plt.plot(CityHotel.index,CityHotel['adr'],label='CityHotel')
plt.plot(ResortHotel.index,ResortHotel['adr'],label='ResortHotel')
plt.legend(fontsize=20)
plt.savefig("ADR of Hotels Date Wise",dpi=300)

# %%
data['month']=data['reservation_status_date'].dt.month
fig=plt.figure(figsize=(18,7))
snb.countplot(x = 'month', hue='is_canceled', data= data, palette='bright')
plt.title("Reservation Status per Month",size=20)
plt.xlabel("Months",size=12)
plt.ylabel("Num of Reservations",size=12)
plt.legend(['Not_canceled','canceled'])
plt.savefig("Reservation_Status_per_Month.png")

plt.show()

# %%
df=data
plt.figure(figsize=(14,5))
plt.title("ADR per month")
ax11=snb.barplot(x= 'month' , y= 'adr',data = df[df['is_canceled']==1].groupby("month")[['adr']].sum().reset_index())
plt.xlabel("Month")
plt.ylabel("ADR")
plt.savefig("ADR per month")
plt.show()

# %%
canceled_=df[df['is_canceled']==1]
top_ten_country=canceled_["country"].value_counts()[:10]

# %%
plt.figure(figsize=(10,5))
plt.title("Top 10 Countries with max canellations")
plt.pie(top_ten_country, autopct='%.1f',labels = top_ten_country.index)
plt.savefig("Top 10 Countries with max canellations")

# %%
df["market_segment"].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %%
canceled_['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1) 
snb.barplot(x=df['market_segment'].value_counts(normalize=True).index,
y=df["market_segment"].value_counts(normalize=True),
palette="Blues_d")
plt.title("Market Segment Distribution (All Bookings)")
plt.ylabel("Percentage")

plt.subplot(2,1,2)
snb.barplot(x=canceled_['market_segment'].value_counts(normalize=True).index,
           y=canceled_['market_segment'].value_counts(normalize=True),
           palette="Reds_d")
plt.title("Market Segment Distribution (Canceled Bookings)")
plt.ylabel("Percentage")
plt.tight_layout()
plt.savefig("Market Segment")
plt.show()
# Out:
# C:\Users\sraj7\AppData\Local\Temp\ipykernel_20116\2887844680.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   snb.barplot(x=df['market_segment'].value_counts(normalize=True).index,
# C:\Users\sraj7\AppData\Local\Temp\ipykernel_20116\2887844680.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   snb.barplot(x=canceled_['market_segment'].value_counts(normalize=True).index,

# %%
not_canceled=df[df["is_canceled"]==0]

# %%
canceled_bookings_adr=canceled_.groupby("reservation_status_date")[["adr"]].mean()
canceled_bookings_adr.reset_index(inplace=True)
canceled_bookings_adr.sort_values("reservation_status_date",inplace=True)

not_canceled_adr=not_canceled.groupby("reservation_status_date")[['adr']].mean()
not_canceled_adr.reset_index(inplace=True)
not_canceled_adr.sort_values("reservation_status_date", inplace=True)

# %%
not_canceled_adr=not_canceled_adr[(not_canceled_adr["reservation_status_date"]>'2016') & (not_canceled_adr["reservation_status_date"]<='2017')]
canceled_bookings_adr=canceled_bookings_adr[(canceled_bookings_adr["reservation_status_date"]>"2016") & (canceled_bookings_adr["reservation_status_date"]<="2017")]

# %%
plt.figure(figsize=(16,5))
plt.plot(canceled_bookings_adr["reservation_status_date"],canceled_bookings_adr["adr"],label="Canceled")
plt.plot(not_canceled_adr["reservation_status_date"],not_canceled_adr["adr"],label=" Not Canceled")
plt.title("ADR rate for canceled and not canceled Reservations", size= 18)
plt.xlabel("Date", size=14)
plt.ylabel("ADR", size=14 )
plt.legend()
plt.savefig("ADR rate for canceled and not canceled Reservations")
